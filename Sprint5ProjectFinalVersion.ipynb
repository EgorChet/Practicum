# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Егор, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Кажется, работа над проектом велась локально и пути к файлам не были изменены на общедоступные. Стоит переписать код таким образом, что бы он запускался и в jupiter hub, и локально без внесения дополнительных правок. Этого можно добиться многими способами. Например, использовать конструкцию try-except для путей файлов: try - пути на локальном компьютере, except - пути на сервере.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Это вроде пофиксил верно? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, теперь корректно) Спасибо за правки

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# Цели исследовательского проекта:
#
# 1. Выявление текущей рыночной ценности объектов недвижимости.
# 2. Разработка системы автоматического мониторинга для обнаружения неправомерных действий и подозрительных аномалий.
# 3. Изучение ключевых факторов, оказывающих влияние на формирование цен на квартиры.
#
# Этапы проведения исследования:
# Информацию о рынке недвижимости я намерен извлечь из файла "/datasets/real_estate_data.csv". Поскольку предварительные сведения о содержимом данных отсутствуют, первым шагом будет тщательный анализ предоставленного файла.
#
# Я проведу диагностику данных на предмет ошибок и оценю, как они могут повлиять на результаты исследования. В ходе предобработки я постараюсь устранить все выявленные недостатки данных, чтобы не допустить искажения выводов. После этого, я добавлю новые расчетные столбцы и начну исследовательский анализ данных.
#
# Исследование будет осуществляться в следующей последовательности:
# • Первичный осмотр данных.
# • Очистка и подготовка данных.
# • Выполнение необходимых расчетов и внесение их в таблицу.
# • Аналитический обзор для объектов в Ленинградской области.
# • Анализ рынка недвижимости Санкт-Петербурга.
# • Сопоставление влияния разных факторов на стоимость квартир в разных регионах.
# • Формирование итоговых выводов по исследованию.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добвил) </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Предлагаю разделять логически разные вещи:
#
#     - импорты библиотек
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спасибо за совет, сделал) </div>

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Done! </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Well done

# %%
data.hist(figsize=(15, 20))
plt.show()

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Исходя из представленного описательного анализа (data.describe()), можно выделить несколько важных наблюдений о наборе данных по недвижимости:
#
# Цены (last_price) имеют значительный разброс, начиная от 12,190 до 763,000,000, что говорит о широком спектре недвижимости, от доступной до эксклюзивной. Средняя цена составляет около 6.54 миллиона, но стандартное отклонение очень велико, что указывает на высокую степень неоднородности ценового сегмента рынка.
#
# Площадь объектов (total_area) также имеет широкий диапазон от 12 до 900 квадратных метров, с медианным значением в 52 квадратных метра, что может говорить о превалировании небольших и средних по размеру квартир в наборе данных.
#
# Число комнат (rooms) варьируется от студий (0 комнат) до крупных квартир и домов (19 комнат), что позволяет анализировать как малогабаритную, так и многокомнатную недвижимость.
#
# Высота потолков (ceiling_height) находится в диапазоне от 1 до 100 метров, но медианное значение 2.65 и среднее 2.77 метра, что является стандартом для современных квартир. Наличие значений выше 100 метров может указывать на выбросы или ошибки в данных.
#
# Расстояние до аэропортов (airports_nearest) и центров городов (cityCenters_nearest) показывает, что квартиры расположены на разном удалении от ключевых инфраструктурных объектов, что может существенно влиять на ценообразование.
#
# Природная доступность, такая как близость к паркам (parks_around3000, parks_nearest) и водоемам (ponds_around3000, ponds_nearest), представлена разнообразно, что позволяет исследовать связь между экологическим расположением и стоимостью недвижимости.
#
# Среднее время продажи (days_exposition) составляет около 180 дней, но стандартное отклонение довольно велико, что указывает на значительные различия в скорости продаж отдельных объектов.
#
# Общий анализ данных указывает на широкий спектр характеристик объектов недвижимости, что требует более глубокого изучения для каждого из интересующих параметров. Наличие пропущенных значений в некоторых ключевых переменных требует внимательной предобработки данных перед дальнейшим анализом. Важно также уделить внимание возможным выбросам, которые могут искажать общую картину, особенно в таких параметрах как высота потолков и цена.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> 👍 </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Пропуски, их возможные причины и методы заполнения:
# 1) ceiling_height - Вероятная причина пропусков заключается в том, что не все пользователи заполняют высоту потолков в объявлениях, либо информация о высоте потолков может быть недоступна. Также, высота потолков обычно имеет стандартизированные значения, и у большинства квартир она будет примерно одинаковой. Поэтому предлагается заполнить пропуски медианным значением столбца "ceiling_height".
#
# 2) floors_total - Похоже, что пропуски в этом столбце возникли из-за неполных данных или нежелания пользователей указывать общее количество этажей в доме. Было решено заполнить пропуски соответствующими значениями из столбца floor
#
# 3) living_area - Возможно, пользователи забывают или не желают указывать общую жилую площадь квартиры. Для заполнения пропусков предлагается вычислить среднюю площадь в зависимости от количества комнат и затем использовать медианное значение жилой площади для квартир с аналогичным количеством комнат.
#
# 4) is_apartment - Пропуски в данном столбце можно безопасно заполнить значением "False", так как вероятно многие пользователи не указывали этот параметр, поскольку их объект недвижимости не является апартаментами.
#
# 5) kitchen_area - Предлагается заполнить пропуски медианными значениями площади кухни в зависимости от количества комнат, а также присвоить значение 0 для студий, так как в студиях обычно нет отдельной кухни.
#
# 6) balcony - Пропуски в данном столбце можно заполнить значением "0", предполагая, что отсутствие информации о балконе означает его отсутствие.
#
# 7) Пропуски в столбцах ["days_exposition","locality_name", "airports_nearest", "cityCenters_nearest", "parks_around3000", "parks_nearest", "ponds_around3000", "ponds_nearest"] вероятно связаны с ошибкой выгрузки или же с отсутвием того или иного обьекта по близости от той или иной квартиры и не могут быть заполнены без дополнительной информации, поэтому они останутся без изменений.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_32589_row0_col0,#T_32589_row1_col0,#T_32589_row2_col0,#T_32589_row3_col0,#T_32589_row4_col0,#T_32589_row6_col0,#T_32589_row8_col0,#T_32589_row10_col0,#T_32589_row11_col0,#T_32589_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_32589_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_32589_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_32589_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_32589_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_32589_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_32589_row15_col0,#T_32589_row16_col0,#T_32589_row17_col0,#T_32589_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> 👍 </div>

# %%
median_ceiling_height = data['ceiling_height'].median()
print(median_ceiling_height)
# Out:
# 2.65

# %%
data['ceiling_height'].fillna(median_ceiling_height, inplace=True)
print(data['ceiling_height'].head(20))
# Out:
# 0     2.70
# 1     2.65
# 2     2.65
# 3     2.65
# 4     3.03
# 5     2.65
# 6     2.65
# 7     2.65
# 8     2.65
# 9     2.50
# 10    2.67
# 11    2.65
# 12    2.65
# 13    2.56
# 14    2.65
# 15    2.65
# 16    3.05
# 17    2.65
# 18    2.50
# 19    2.75
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].isna().sum()
# Out:
# 0

# %%
missing_floors = data[data['floors_total'].isna()]
print(missing_floors[['floors_total','floor']].head(60))
missing_floors['floors_total'].isna().sum()
# Out:
#        floors_total  floor
# 186             NaN      4
# 237             NaN      1
# 457             NaN     12
# 671             NaN      8
# 1757            NaN      9
# 1930            NaN      4
# 2392            NaN     22
# 2846            NaN     15
# 2952            NaN      6
# 3031            NaN     12
# 3438            NaN     12
# 3817            NaN      1
# 3831            NaN      7
# 4140            NaN      3
# 4617            NaN     12
# 4848            NaN     18
# 4901            NaN      6
# 5146            NaN     12
# 5187            NaN     15
# 5784            NaN     18
# 5958            NaN     13
# 6030            NaN     24
# 6136            NaN      6
# 6288            NaN      8
# 7508            NaN      8
# 7662            NaN      6
# 7922            NaN     24
# 8478            NaN     21
# 8986            NaN      4
# 9023            NaN     11
# 9415            NaN      8
# 9979            NaN      2
# 10004           NaN      5
# ...

# %%
data['floors_total'] = data['floors_total'].fillna(data['floor'])
data['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Замена на медиану не всегда хорошо. Давай представим ситуацию на примере этажности дома. Медиана = 9 этажей. Но в строке датасета у пользователя указано, что он живет на 12 этаже но пропуск в этажности дома. Итого получается карлсон
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Этот код присваивает  пропущеным значениям из столбца floors_total соответствующие значения из столбца floor. Так посоветовали ребята из чата в tg. Но если честно я сомневаюсь что это верно ибо этот метод заполнения имеет смысл только в том случае, если бы мы были уверены, что квартиры с пропущенным значением floors_total действительно находятся в здании с числом этажей, равным этажу квартиры (то есть квартира расположена на последнем этаже). Это довольно сильное предположение, которое может не соответствовать действительности. Так же это решение повлияет на наш последующий анализ стоимости квартир по типу этажа (первый, последний, другой) так как мы все эти пропуски записали на последний этаж.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Реализация в 13 ячейке логична и имеет место быть)

# %%
data['floors_total'].isna().sum()
# Out:
# 0

# %%
print(data['living_area'].head(20))
print(data['rooms'].head(20))
# Out:
# 0     51.00
# 1     18.60
# 2     34.30
# 3       NaN
# 4     32.00
# 5     14.40
# 6     10.60
# 7       NaN
# 8     15.43
# 9     43.60
# 10    20.30
# 11    31.00
# 12    30.00
# 13    27.00
# 14    17.00
# 15    20.50
# 16    55.60
# 17    16.50
# 18    19.40
# 19    76.00
# Name: living_area, dtype: float64
# 0     3
# 1     1
# 2     2
# 3     3
# 4     2
# 5     1
# 6     1
# 7     2
# 8     1
# 9     3
# 10    1
# 11    2
# 12    2
# 13    2
# 14    1
# 15    1
# 16    3
# 17    1
# 18    1
# 19    3
# Name: rooms, dtype: int64

# %%
for number in data['rooms'].unique():
    data.loc[(data['rooms'] == number) & (data['living_area'].isna()), 'living_area'] = \
    data.loc[(data['rooms'] == number), 'living_area'].median()
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что используешь собственные функции

# %%
data['is_apartment'].fillna(False, inplace=True)
data['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верно, ведь это булевый столбец

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %%
for number in data['rooms'].unique():
        data.loc[(data['rooms'] == number) & (data['kitchen_area'].isna()), 'kitchen_area'] = \
        data.loc[(data['rooms'] == number), 'kitchen_area'].median()
data['kitchen_area'].isna().sum()
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# 197

# %%
kitchen_area_nan = data[data['kitchen_area'].isna()]
print(kitchen_area_nan.head(50))
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 144              1   2450000.0       27.00  2017-03-30T00:00:00      0
# 349              4   2320000.0       25.00  2017-09-27T00:00:00      0
# 440              8   2480000.0       27.11  2018-03-12T00:00:00      0
# 508              0   3375000.0       34.40  2017-03-28T00:00:00      0
# 608              2   1850000.0       25.00  2019-02-20T00:00:00      0
# 697             12   2500000.0       24.10  2017-12-01T00:00:00      0
# 716              5   1500000.0       17.00  2017-06-07T00:00:00      0
# 780              9   2600000.0       26.10  2018-02-20T00:00:00      0
# 839             14   1900000.0       35.00  2017-04-14T00:00:00      0
# 946              5   2200000.0       23.00  2016-09-27T00:00:00      0
# 1173            12   3240000.0       29.00  2018-10-30T00:00:00      0
# 1174             3   3900000.0       32.00  2016-10-18T00:00:00      0
# ...

# %%
print(data.loc[data['kitchen_area'].isna() & (data['studio'] == True), 'studio'].count())
print(data.loc[data['kitchen_area'].isna() & (data['rooms'] == 0), 'studio'].count())

197-138
# Out:
# 138
# 197
# 59

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Судя по всему, 59 человек не хотят признавать свои квартиры студиями. Однако, поскольку они указали, что в их квартирах 0 комнат, мы можем заполнить оставшиеся пропуски следующим кодом: </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Если пропусков меньше 5-10%, их можно удалить, по причине малочисленности

# %%
for number in data['rooms'].unique():
    if number == 0:
        data.loc[(data['rooms'] == number) & (data['kitchen_area'].isna()), 'kitchen_area'] = 0
data['kitchen_area'].isna().sum()
# Out:
# 0

# %%
data['balcony'].fillna(0, inplace=True)
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Не обязательно заполнять все пропуски. Например в столбце `days_exposition` я бы рекомендовал их оставить, как есть. Т.к. любая замена - это или случайное число или заглушка. Которые исказят результаты исследовательского анализа
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Убрал👍 </div>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# #### Типы данных и причины их изменения.

# %%
data.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment               bool
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %%
data[['floors_total', 'balcony']] = data[['floors_total', 'balcony']].astype('int64')
data['day_exposition'] = data['day_exposition'].astype('Int64', errors='ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'day_exposition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48/2064984387.py in <module>
# ...

# %%
data['first_day_exposition'].head(20)

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'])
data['first_day_exposition'].head(20)

# %%
print(data['is_apartment'].unique())
print(data['studio'].unique())
print(data['open_plan'].unique())

# %% [markdown]
# **В процессе предобработки данных** были выявлены и решены некоторые важные вопросы относительно типов данных в столбцах. В частности, для столбца "first_day_exposition", содержащего даты, была выполнена важная операция преобразования его типа данных в datetime. Это изменение позволит более эффективно и удобно работать с датами и выполнять различные датасвязанные операции.
#
# Столбцы 'balcony', 'floors_total' были перведены в формат 'int64' так как являются целыми числами.
#
# Также было проведено обращение к булевым столбцам "is_apartment," "studio," и "open_plan" для того чтобы убедиться, что они содержат только допустимые булевы значения (True/False). Все значения в этих столбцах оказались корректными, что подтверждает их соответствие заданному формату данных.
#
# В остальном, структура данных выглядит правильно и готова к дальнейшему анализу и использованию для выявления интересных закономерностей и вывода информации.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Не все столбцы имеют корректный тип данных. Например `balcony` имеет дробный тип. Но ведь не может быть 1.5 балкона в доме. Как думаешь?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Вроде все поправил 👍 пытался так же перевести day_exposition в int64 но он не хочет из за пропусков а пропуски мы решили не заполнять </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №2__
#
# Можно вот так:
#
#     data[''] = data[''].astype('Int64', errors='ignore')

# %% [markdown]
# #### Устранение неявных дубликатов в названиях населённых пунктов.

# %%
print(data.duplicated().sum()) 
print()
print(data['locality_name'].value_counts().head(60))
print()
print(len(data['locality_name'].unique()))

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на явные дубликаты - основа предобработки данных

# %%
data['locality_name'] = data['locality_name'].replace('ё', 'е', regex=True)
print(data['locality_name'].value_counts().count())

# %%
prefixes = [
    'садоводческое некоммерческое товарищество ',
    'село ',
    'садовое товарищество ',
    'городского типа ',
    'городской ',
    'деревня ',
    'поселок ',
]

for prefix in prefixes:
    data['locality_name'] = data['locality_name'].str.replace(prefix, '')

print(data['locality_name'].value_counts().count())

# %% [markdown]
# **Вывод:** В процессе предобработки данных была проведена очистка названий населённых пунктов от неявных дубликатов. Неявные дубликаты возникают, когда один и тот же населённый пункт может быть записан в разных вариациях. Например, наличие префиксов "село", "деревня", "посёлок" перед названием могло приводить к тому, что одно и то же место считалось разными населёнными пунктами.
#
# Путём удаления данных префиксов, а также замены "ё" на "е", количество уникальных наименований населённых пунктов уменьшилось с 365 до 309. Это позволяет более точно анализировать данные, поскольку исключает повторы и расхождения, вызванные различиями в названиях.
#
# Процедура устранения неявных дубликатов подчеркивает важность тщательной предобработки данных перед проведением анализа. Качество исходных данных оказалось неидеальным, и такие несоответствия могли внести существенные искажения в результаты исследования. Очистка данных от подобных ошибок помогает повысить надёжность и точность выводов, которые можно сделать на основе анализа.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Все конечно правильно, но процесс стоит оптимизировать. Можно же просто replace('посёлок', 'поселок') или просто все ё заменить на е
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Вроде теперь по аккуратнее выглядит </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Добавление в таблицу новых столбцов необходимых для дальнейшего анализа данных.

# %%
data.info()

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
print(data['last_price'].head())
print(data['living_area'].head())
data['price_m2'] = (data['last_price'] / data['living_area'])
print(data['price_m2'].head())

# %%
print(data['first_day_exposition'].head())

# %%
data['day_of_week_publication'] = data['first_day_exposition'].dt.weekday
data['month_of_publication'] = data['first_day_exposition'].dt.month
data['year_of_publication'] = data['first_day_exposition'].dt.year
print(data[['year_of_publication', 'month_of_publication', 'day_of_week_publication']].head())

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://runebook.dev/ru/docs/numpy/reference/arrays.datetime
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спасибо за совет обязательно учту 👍 </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %%
def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
data['floor_type'] = data.apply(floor_type, axis=1)
print(data['floor_type'].head(13))

# %%
data['city_center_distance_km'] = (data['cityCenters_nearest'] / 1000).round(0)
print(data['city_center_distance_km'].head(20))

# %% [markdown]
# **В этом раздеде мы добавили следующие столбцы:**
#
# цену одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
# день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# месяц публикации объявления;
# год публикации объявления;
# тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %%
data.info()

# %%
data[['living_area','total_area','kitchen_area', 'last_price', 'rooms', 'ceiling_height', 'floor_type', 'floors_total', 'price_m2', 'parks_nearest', 'city_center_distance_km',]].describe()

# %% [markdown]
# **living_area** - Минимальное значение в 2 квадратных метра звучит нереалистично, так же как и максимальное значение в 410 квадратных метров, но последнее хотя бы можно себе представить.
#
# **total_area** - Минимальные и максимальные значения в 12 и 900 квадратных метров соответственно также кажутся не совсем правдоподобными.
#
# **kitchen_area** - Максимальное значение в 112 квадратных метров для площади кухни выглядит необычно.
#
# **last_price** - Минимальная цена в 12,190 рублей и максимальная в 763 миллиона рублей также вызывают сомнения.
#
# **rooms** - Наличие 19 комнат в одной квартире выглядит тоже неправдоподобно
#
# **ceiling_height** - Однако потолки в 100 метров кажутся абсолютно нереалистичными, и также потолки в 1 метр маловероятны. Жить с такой высотой потолков было бы неудобно.
#
# **floors_total** - Если в доме 60 этажей, это может быть только Лахта Центр в Санкт-Петербурге.
#
# **price_m2** - Цена более 21 миллиона рублей за квадратный метр кажется неправдоподобной, такие цены обычно не существуют. Аналогично, цена в 380 рублей за квадратный метр также выглядит странной.
#
# Обнаруженные аномалии требуют более детального рассмотрения и, возможно, коррекции данных.

# %%
import pandas as pd

def remove_outliers(data, column, iqr_multiplier):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - (iqr_multiplier * IQR)
    upper_bound = Q3 + (iqr_multiplier * IQR)
    outliers_removed = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
    return outliers_removed

columns_to_check = ['living_area', 'total_area', 'kitchen_area', 'last_price', 'rooms', 'ceiling_height', 'price_m2']

for column in columns_to_check:
    data = remove_outliers(data, column, 3)

# %%
data[['living_area','total_area','kitchen_area', 'last_price', 'rooms', 'ceiling_height', 'floor_type', 'floors_total', 'price_m2', 'parks_nearest', 'city_center_distance_km',]].describe()

# %%
data = data[data['floors_total'] <= 35]

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Попробовал функцию с IQR все вроде получилось но осталось всего 17000 из 23699. Почитал говорят в исключительных случаях можно делать iqr_miltiplier не 1.5 а например 3 чтобы быть менее строгим к границам выбросов и сохранить больше данных. Установил множитель IQR равный 3 и применил к нашим данным на мой взгляд выглядит куда лучше сохранилось 20913 из 23699 что скажешь? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Хороший вопрос: Расчёт по IQR показываешь лишь математически "границы выбросов". Рекомендую только описаться на эти данные, и срезать если ты действительно уверен, что это аномалии. Например высота потолков - 30 метров - явная аномалия. А цена 100млн за недвижку - вполне адекватно

# %%
data[['living_area','total_area','kitchen_area', 'last_price', 'rooms', 'ceiling_height', 'floor_type', 'floors_total', 'price_m2', 'parks_nearest', 'city_center_distance_km',]].describe()

# %%
plt.figure(figsize=(8, 4))
data['living_area'].hist(bins=30)
plt.title('Distribution of Living Area')
plt.xlabel('Living Area (sq. meters)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['total_area'].hist(bins=30)
plt.title('Distribution of Total Area')
plt.xlabel('Total Area (sq. meters)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['kitchen_area'].hist(bins=30)
plt.title('Distribution of Kitchen Area')
plt.xlabel('Kitchen Area (sq. meters)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['last_price'].hist(bins=30)
plt.title('Distribution of Last Price')
plt.xlabel('Last Price (rubles)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['ceiling_height'].hist(bins=30)
plt.title('Distribution of Ceiling Height')
plt.xlabel('Ceiling Height (meters)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['floors_total'].hist(bins=30)
plt.title('Distribution of Total Floors in Building')
plt.xlabel('Total Floors')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['price_m2'].hist(bins=30)
plt.title('Distribution of Price per Square Meter')
plt.xlabel('Price per Square Meter (rubles/sq. meter)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
data['rooms'].hist(bins=30)
plt.title('Distribution of the Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Я не уверен, что выполнил данное задание правильно. Я просто, на свое усмотрение, прикинул реалистичные параметры для каждого анализируемого столбца и отфильтровал данные. Затем, на всякий случай, я проверил, что отфильтровалась лишь малая часть общей таблицы. А значит, были затронуты только аномалии, которые я и хотел отбросить. </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: Рекомендую не смотреть данные "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их (если они соответствуют здравому смыслу). В этом поможет метод boxplot()
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Рекомендую не писать весь код в одной ячейке. Лучше после каждого раздела, графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи - так проще читать проект, поскольку будущим коллегам или заказчику не надо будет самим интерпретировать результаты каждого раздела, теста или графика.

# %% [markdown]
# ###  Анализ скорости продажи квартир.

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Ранее я заполнил пропуски в столбце ['days_exposition'] значением -1, так как предположил, что эти объявления еще активны. Для того чтобы выполнить следующее задание, я удалю эти значения, чтобы они не влияли на результат исследования. Я не уверен, что это верное решение, так как там было много пропусков (3181 из 23699, что составляет 13,5%), но я не знаю, будет ли правильным заполнять пропуски с помощью .median() в данном случае.
#
# "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
# Постройте гистограмму.
# Посчитайте среднее и медиану.
# В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?" </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Верно, что исключаешь заглушку. Это правильный ход. Но заменять пропуски на рандомную медиану - это плохая практика. Рекомендую оставить пропуски в их изначальном виде. Т.к. ничем логичным нам их не заменить

# %%
data['days_exposition'].describe()

# %%
plt.figure(figsize=(10, 5))
data.boxplot(column=['days_exposition'])
plt.title('Boxplot of Days Exposition')
plt.ylabel('Days')
plt.show()

# %%
describe_day_exposition = data['days_exposition'].describe()

Q1 = describe_day_exposition['25%']
Q3 = describe_day_exposition['75%']
IQR = Q3 - Q1

fast_sales_threshold = Q1 - 1.5 * IQR
if fast_sales_threshold < 0:
    fast_sales_threshold = 30

slow_sales_threshold = Q3 + 1.5 * IQR

print(f"Продажи быстрые, если они завершаются менее чем за {fast_sales_threshold} дней.")
print(f"Продажи долгие, если они завершаются более чем за {slow_sales_threshold} дней.")

# %% [markdown]
# **Вывод:**
#
# Среднее значение ('mean') времени продажи составляет около 180.89 дней, а медианное значение ('median') составляет 95 дней. Эти статистики помогают понять общее распределение времени продажи и показывают, что в среднем продажа квартиры занимает примерно полгода, а медианное значение указывает на то, что большинство квартир продается в течение 3 месяцев.
#
# Обычно продажа недвижимости занимает от 3 до 6 месяцев. Продажи, которые завершаются менее чем за 3 месяца, можно считать быстрыми. В то же время, продажи, которые длительность которых превышает полгода, могут считаться необычно долгими. Долгий срок продажи может быть связан с различными факторами, такими как высокая цена, необычные характеристики объекта недвижимости или неэффективной стратегией продажи. Важно отметить, что величина, считающаяся "обычной" или "быстрой", может варьироваться в зависимости от конкретного рынка недвижимости и локации.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данных с помощью boxplot() или describe().
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Вроде починил так как slow_sales_threshold получается негативной задал ей значение 30 мне показалось что так будет логично ? что скажешь? </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Я бы рекомендавал брать 25% и 75% распределение данных за быстрые и долгие сооветственно
# </div>

# %% [markdown]
# ### Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %%
pearson_correlation = data['total_area'].corr(data['last_price'])
print(f"Коэффициент корреляции Пирсона между общей площадью и ценой продажи: {pearson_correlation}")

# %%
data.plot(x='total_area', y='last_price', kind='scatter', alpha=0.2)

# %% [markdown]
# Коэффициент корреляции между общей площадью и ценой продажи равен 0.753. Это указывает на сильную положительную линейную зависимость. То есть с увеличением общей площади цена продажи обычно тоже увеличивается.
#
# Эти данные могут быть полезны при оценке недвижимости, поскольку они показывают, как различные характеристики свойства (например, площадь) связаны с его ценой на рынке. Однако стоит помнить, что корреляция не обязательно указывает на причинно-следственную связь, а лишь на степень линейной связи между переменными.
#
# Из графика видно, что большинство точек сосредоточено в нижнем левом углу, что указывает на то, что большинство квартир имеют меньшую общую площадь и соответственно ниже цену. С увеличением общей площади (двигаясь вправо по оси X) количество квартир уменьшается, и они распределяются более свободно по вертикали, что говорит о различиях в ценах.
#
# Также заметна тенденция: с увеличением площади квартиры цена также увеличивается, что является ожидаемым, так как большие квартиры обычно дороже. Однако, также видно, что при одинаковой площади квартир цены могут значительно варьироваться, что может быть обусловлено множеством других факторов, таких как местоположение, состояние квартиры, этаж, наличие удобств и др.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Давай графики зависимостей нелинейных данных (площади) подкрепим корреляцией Пирсона и сразу интерпретировать полученные данные в разделе?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Верная интерпретация значений корреляции Пирсона. Ты молодец =)
# </div>

# %%
pearson_correlation = data['living_area'].corr(data['last_price'])
print(f"Коэффициент корреляции Пирсона между жилой площадью и ценой продажи: {pearson_correlation}")

# %%
data.plot(x='living_area', y='last_price', kind='scatter', alpha=0.2)

# %% [markdown]
# Коэффициент корреляции между жилой площадью и последней ценой продажи равен 0.657. Это также указывает на положительную линейную зависимость, но она не такая сильная, как между общей площадью и ценой. Жилая площадь также важный фактор в определении цены продажи, но влияние её на цену не такое велико, как у общей площади.
#
# Точки на диаграмме сконцентрированы в основном в левой нижней части, указывая на большое количество квартир с меньшей жилой площадью и более низкой ценой. Можно также заметить, что с увеличением жилой площади цены на квартиры в среднем увеличиваются, но также существует значительный разброс цен даже среди квартир с схожей жилой площадью. Также стоит отметить, что с увеличением размера и соответственно цены квартир жилая площадь начинает все меньше влиять на цену, так как в верхней части графика видны квартиры с широким диапазоном жилых площадей, имеющие высокие цены.

# %%
pearson_correlation = data['kitchen_area'].corr(data['last_price'])
print(f"Коэффициент корреляции Пирсона между площадью кухни и ценой продажи: {pearson_correlation}")

# %%
data.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.2)

# %% [markdown]
# Коэффициент корреляции между площадью кухни и последней ценой продажи равен 0.494. Это указывает на умеренную положительную линейную зависимость. Площадь кухни влияет на цену продажи, но это влияние меньше, чем у общей или жилой площади.
#
# Точки на диаграмме в основном сосредоточены в нижней части оси Y, что снова указывает на большое количество квартир с относительно низкой стоимостью. Как видно, с увеличением площади кухни, цена квартир также имеет тенденцию к повышению, однако разброс цен остаётся значительным на всём диапазоне площадей кухни. Важно отметить, что количество квартир с площадью кухни более 10 квадратных метров заметно уменьшается, и цены на такие квартиры могут значительно варьироваться, что свидетельствует о влиянии иных характеристик квартир, помимо размера кухни, на их стоимость.

# %%
data = data[data['rooms'] <= 7]
print('Количество записей:', data['rooms'].count())
room_price = data.pivot_table(index='rooms', values='last_price', aggfunc='median')
room_price.plot(kind='bar', legend=False)

# %% [markdown]
# На представленной гистограмме показана медианная цена квартир в зависимости от количества комнат. Очевидно, что с увеличением количества комнат медианная цена квартир растёт. Наименьшая медианная цена наблюдается для квартир с одной комнатой, и цена увеличивается с каждым дополнительным номером комнаты, достигая пика для квартир с семью комнатами.
#
# Интересно отметить, что рост медианных цен кажется довольно последовательным от одной до четырех комнат, после чего наблюдается более крупный скачок между пятикомнатными и шестикомнатными квартирами, а также между шестикомнатными и семикомнатными квартирами. Это может указывать на то, что квартиры с большим количеством комнат воспринимаются как более премиальные или редкие, что ведёт к их более высокой стоимости.

# %%
floor_price = data.pivot_table(index='floor_type', values='last_price', aggfunc='median')
floor_price.plot(kind='bar', legend=False)

# %% [markdown]
# Исходя из графика, видно, что квартиры на первом этаже в среднем имеют более низкую стоимость, чем квартиры на других этажах. Квартиры на последнем этаже также, как правило, дешевле, чем квартиры, расположенные между первым и последним этажами.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %%
day_of_week_price = data.pivot_table(index='day_of_week_publication', values='last_price', aggfunc='median')

day_of_week_price.plot(kind='bar', figsize=(6, 3))
plt.title("Зависимость цены от дня недели размещения")
plt.xlabel("День недели размещения")
plt.ylabel("Медианная цена")
plt.show()

# %% [markdown]
# На графике отображены дни недели, начиная с понедельника (0) и заканчивая воскресеньем (6). Медианные цены недвижимости, по-видимому, не показывают значительных колебаний в зависимости от дня недели, когда было размещено объявление. Это может указывать на то, что фактор дня недели размещения объявления не оказывает значительного влияния на медианную цену объектов недвижимости в данном наборе данных.

# %%
month_price = data.pivot_table(index='month_of_publication', values='last_price', aggfunc='median')

month_price.plot(kind='bar', figsize=(6, 3))
plt.title("Зависимость цены от месяца размещения")
plt.xlabel("Месяц размещения")
plt.ylabel("Медианная цена")
plt.show()

# %% [markdown]
# Согласно графику, медианная цена недвижимости колеблется от месяца к месяцу, но не показывает явного тренда увеличения или уменьшения в течение года.

# %%
year_price = data.pivot_table(index='year_of_publication', values='last_price', aggfunc='median')

year_price.plot(kind='bar', figsize=(6, 3))
plt.title("Зависимость цены от года размещения")
plt.xlabel("Год размещения")
plt.ylabel("Медианная цена")
plt.show()

# %% [markdown]
# На графике видно, что медианная цена сильно упала в 2015 году и 2016 году. Затем медианная цена стабилизировались и оставалась относительно постоянной с 2016 по 2018 годы. В 2019 году наблюдается незначительное увеличение медианной цены по сравнению с предыдущим годом. Эти данные могут быть полезны для анализа рыночных тенденций и прогнозирования будущих изменений стоимости недвижимости. Далее мы подробнее рассмотрим причину столь высокой медианной цены в 2014 году.

# %%
annual_stats = data.groupby('year_of_publication').agg({'last_price': 'mean', 'total_area': 'mean'}).reset_index()

plt.figure(figsize=(10, 5))
plt.plot(annual_stats['year_of_publication'], annual_stats['total_area'], '-o')
plt.title('Динамика средней общей площади по годам')
plt.xlabel('Год')
plt.ylabel('Средняя общая площадь')
plt.grid(True)
plt.show()

# %% [markdown]
# Из графика четко прослеживается общая тенденция на уменьшение общей площади выставленных на продажу квартир. Осмелюсь предположить что это связанно с общемировой тенденцией на уменьшее площади жилья.
#
# Уменьшение площади жилья — это тенденция, которая наблюдается во многих странах мира, и она в основном обусловлена нарастающей урбанизацией.
#
# Урбанизация: По мере того как все больше людей переезжают в города в поисках работы и лучших возможностей, спрос на жилье в городах увеличивается. Это приводит к повышению стоимости земли и, как следствие, к строительству более мелких жилых единиц, чтобы сделать их более доступными.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# **Вывод:**
#
# **Зависимость цены от года размещения:** Зависимости цены от года размещения мы не обноружили зато в процессе заметили что средняя площадь выставленных на продажу квартир не уклонно падает с 2014 по 2018 год. Уменьшение площади жилья — это тенденция, которая наблюдается во многих странах мира, и она в основном обусловлена нарастающей урбанизацией.
#
# **Зависимость цены от дня и месяца размещения:** Медианная цена кажется относительно стабильной как в течение месяца так и в течении недели.
#
# **Зависимость цены от общей площади, жилой площади, и площади кухни:** Цена значительно увеличивается с ростом общей площади, что является ожидаемой тенденцией, поскольку большая площадь часто коррелирует с более высокой стоимостью недвижимости. Подобно общей площади, цена увеличивается вместе с увеличением жилой площади но уже не так явно. Цена также повышается с ростом площади кухни но уже совсем не так явно и очевидно как в предидущих двух случаях.
#
# **Зависимость цены от количества комнат:** Интересно отметить, что рост медианных цен кажется довольно последовательным от одной до пяти комнат, после чего наблюдается более крупный скачок между пятикомнатными и шестикомнатными квартирами, а также между шестикомнатными и семикомнатными квартирами.
#
# **Зависимость цены от типа этажа:** Квартиры, расположенные не на первом и не на последнем этаже, имеют более высокую медианную цену, что может быть связано с предпочтениями покупателей, связанными с безопасностью, шумом, видом из окон и другими факторами.

# %% [markdown]
# ### Средняя цена m2 в 10 населённых пунктах с наибольшим числом объявлений.

# %%
top_10_localities = data['locality_name'].value_counts().head(10)
print(top_10_localities)

# %%
grouped_data = data.groupby('locality_name')
summary_table = grouped_data.agg({'price_m2':'median', 'total_images':'count'})
summary_table.rename(columns={'price_m2': 'Median_Price_per_m2', 'total_images': 'Number_of_Listings'}, inplace=True)
top_localities = summary_table.sort_values(by='Number_of_Listings', ascending=False).head(10)
top_localities

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Расчёт верный

# %% [markdown]
#  **Вывод:**
# Средняя цена за квадратный метр жилья имеет значительные различия в различных населенных пунктах. Наивысшая средняя цена за квадратный метр наблюдается в Парголово (197,952.22 рубля за квадратный метр), а наименьшая в Выборге (93,333.33 рубля за квадратный метр).
#
# Интересно, что средняя цена за квадратный метр в Парголово выше, чем в Санкт-Петербурге. Это может быть связано с особенностями предложения и спроса на жилье в данном районе.
#
# Количество объявлений о продаже недвижимости также разнится в зависимости от населенного пункта. Самое большое количество объявлений относится к Санкт-Петербургу (15,310 объявлений).
#
# Важно также обратить внимание на высокое количество объявлений в Мурино и Кудрово, при средних ценах за квадратный метр, близких к уровню Санкт-Петербурга. Это может указывать на активный рынок недвижимости и интерес со стороны покупателей в этих районах.

# %%
spb_data = data[data['locality_name'] == 'Санкт-Петербург']
spb_data_grouped = spb_data.groupby('city_center_distance_km').agg(
    last_price=('last_price', 'mean'),
    number_of_listings=('last_price', 'count')
).reset_index()
spb_data_grouped['last_price'] = spb_data_grouped['last_price'] / 1000000

plt.figure(figsize=(10, 5))
plt.plot(spb_data_grouped['city_center_distance_km'], spb_data_grouped['last_price'], '-o')
plt.title('Средняя стоимость квартиры в зависимости от расстояния до центра')
plt.xlabel('Расстояние до центра (км)')
plt.ylabel('Средняя цена (млн рублей)')
plt.grid(True)
plt.show()

spb_data_grouped.head(10)

# %% [markdown]
# <div class="alert alert-info"> <b> Комментарий студента:</b> Полечил должно работать </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличная визуализация.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Падает код ![image.png](attachment:image.png)

# %% [markdown]
# На графике показана средняя стоимость квартир в зависимости от расстояния до центра города в километрах. Из графика видно, что:
#
# Цена на квартиры существенно снижается с увеличением расстояния от центра: особенно резкое падение наблюдается в первых 2-3 километрах. Дальше мы видим, небольшой всплеск в районе 6 км. Затем цена продолжает уменьшаться, но менее интенсивно, и достигает минимума примерно на отметке в 27 км.
#
# Однако есть интересный всплеск в районе 27-30 км, где средняя цена вновь поднимается. Это может быть связано с наличием какого-то престижного жилого района на этом удалении от центра, либо с особенностями доступности инфраструктуры или природных условий.
#
# Этот график помогает понять, как расстояние до центра города влияет на стоимость недвижимости и может быть важным фактором для инвесторов и покупателей при принятии решений о покупке.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В рамках исследования рынка недвижимости был проведен тщательный анализ данных, включающий этап предобработки. На этом этапе мы успешно справились с выбивающимися значениями и адаптировали типы данных для удобства дальнейшего анализа. Важной частью работы стало вычисление необходимых параметров и их интеграция в основную таблицу, что позволило нам расширить возможности для изучения взаимосвязей между различными переменными. Также была проведена стандартизация названий населенных пунктов для исключения дублирования данных.
#
# В процессе работы мы столкнулись с пропусками в данных, которые могли возникнуть по разным причинам, включая ошибки ввода или особенности сбора информации. Для решения этой проблемы мы применили заполнение медианными значениями и нулями, что позволило нам максимально точно восстановить исходную информацию.
#
# Оценивая длительность продажи, мы установили, что типичный срок реализации недвижимости составляет от 3 до 6 месяцев. Более быстрые сделки, оформляемые менее чем за 3 месяца, и длительные продажи, превышающие 6 месяцев, являются скорее исключением из правил и могут указывать на отклонения в ценообразовании или специфику объекта.
#
# Анализ факторов, влияющих на стоимость недвижимости, показал, что наиболее сильное влияние оказывает общая площадь квартир. Местоположение объектов, особенно в крупных городах как Санкт-Петербург, играет значительную роль, подтверждая тесную связь между стоимостью жилья и его расположением относительно центра города.
#
# Мы отметили изменения на рынке, такие как резкое падение медианной площади квартир в 2014 году и последующий тренд на уменьшение площади.
#
# Также было выявлено, что квартиры, расположенные на средних этажах, ценятся выше по сравнению с крайними этажами. Это может быть обусловлено рядом факторов, включая предпочтения покупателей, связанные с безопасностью и комфортом проживания.
#
# В заключение, Санкт-Петербург остается лидером по количеству предложений на рынке недвижимости, что логично учитывая его размер и статус. При этом некоторые пригороды, такие как Парголово, Мурино и Кудрино, демонстрируют высокие цены, что может отражать растущий интерес к жилью в новостройках и желание жить в близости к природе, сохраняя доступность городской инфраструктуры.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Замена пропусков
#
# 2) Типы данных
#
# 3) Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# 4) Корреляция Пирсона
#
# 5) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 6) Падает код
#
# 7) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
